# %% [markdown]
# # 🤖 **Práctica 09: Clustering-Sando a José Madero** 🐼
# ----
#
# ## <b>T</b><b>e</b><b>a</b><b>m</b>: <font color='red'><b>S</b></font><b>ocios</b> <font color='blue'><b>I</b></font><b>nteligentemente</b> <font color='green'><b>A</b></font><b>rtificiales</b> (<font color='red'><b>S</b></font>.<font color='blue'><b>I</b></font>.<font color='green'><b>A</b></font>)
#
# <br>
# <a href="https://www.youtube.com/watch?v=B6hc3Cjyys0">
# <img src="https://media.tenor.com/PZyuRn_vn5YAAAAi/triforce.gif" width="40">
# </a>  <strong>Araujo Chávez Mauricio</strong>
# <br>
#
# <br>
# <a href="https://www.youtube.com/watch?v=yeY81At_6L4">
# <img src="https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/5589a669-9b78-41ae-8414-fa7bea390bd1/d1r9m4i-327eb7c3-b511-4eba-90cb-51519befab8a.gif?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..nU8mlYNu3K_xVKIave0nmNYlFJ2Pz8uW_PtrIbO8g80" width="40">
# </a>  <strong>Bonilla Reyes Dafne</strong>
# <br>
#
# <br>
# <a href="https://www.youtube.com/watch?v=bqwLVQ7uv1c">
# <img src="https://media.tenor.com/m6cM9lV-doYAAAAi/batman-batman-beyond.gif" width="40">
# </a>  <strong>Castañón Maldonado Carlos Emilio</strong>
# <br>
#
#
# <br>
# <a href="https://www.youtube.com/watch?v=la6rFFSFPhg">
# <img src="https://i.pinimg.com/originals/9c/40/eb/9c40eb371f746929e1cb477da963e7a5.gif" width="40">
# </a>  <strong>Clemente Herrera Karla</strong>
# <br>
#
#
# <br>
# <a href="https://www.youtube.com/watch?v=tTZ18m4W3gY">
# <img src="https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/3f8e7cb6-257a-4785-a420-51b3ef31892d/dfnemnj-c4089427-4907-4426-b93b-3aec6e05502e.gif?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..4KO7UB3C_kGhJNVi8BPrSWWoFSZ7LO-XAYGcRe2_HL4" width="40">
# </a>  <strong>Mares Cruz Tlacaelel Horacio</strong>
# <br>
#
#
# <br>
# <a href="https://www.youtube.com/watch?v=kP6_nlTdPgI">
# <img src="https://i.pinimg.com/originals/80/7b/5c/807b5c4b02e765bb4930b7c66662ef4b.gif" width="40">
# </a>  <strong>Navarro Santana Pablo César</strong>
# <br>

# %% [markdown]
# <div align="center">
#
# [![](https://i.makeagif.com/media/3-23-2014/iHl0jL.gif)](https://www.youtube.com/watch?v=la6rFFSFPhg)
#
# </div>

# %%
# En caso de no tener instalado las siguientes librerias, instalar con:
# !pip install numpy
# !pip install matplotlib
# !pip install pandas
# !pip install seaborn
# !pip install nltk
# !pip install -U scikit-learn
# !pip install joblib # Este ya deberia estar instalado con scikit-learn

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

import pandas as pd
import seaborn as sns

import sklearn as sk
from sklearn import *
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error

from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, recall_score, precision_score, f1_score
from sklearn.metrics import r2_score

from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.svm import SVC
from sklearn.cluster import KMeans
from sklearn.decomposition import TruncatedSVD



# %matplotlib inline

# %%
import re
import nltk
from nltk.corpus import stopwords

# nltk.download('stopwords') # Descomentar en caso de no contar con las stopwords
# stop_words = set(stopwords.words('english'))

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import glob
import os
import unicodedata
import string

# %% [markdown]
# ### 📊 **Cargamos los Datos**

# %%
'''
Implementa una funcion para cargar los archivos .txt desde un directorio
en especifico. Asegurate de que la funcion lea solo archivos de textos y capture tanto
el contenido del texto como el nombre del archivo.
'''
all_letters = string.ascii_letters + " .,;'-"
n_letters = len(all_letters) + 1 # mas uno para marcar el final.

# Funcion auxiliar que devuelve los nombres de los archivos txt de una carpeta.
def findFiles(path): return glob.glob(path + '/*.txt')

def unicodeToAscii(s):
    '''
    Funcion auxiliar para transformar elementos de UNICODE a ASCII
    '''
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
        and c in all_letters
    )

def readLines(filename):
    '''
    Funcion auxiliar para leer las lineas 
    '''
    lines = open(filename, encoding='utf-8').read().strip().split('\n')
    return [unicodeToAscii(line) for line in lines]

category_lines = {}
all_categories = []

def leerArchivosCarpeta(data_path):
    '''
    Funcion para leer los archivos txt de una carpeta
    '''
    category_lines = {}
    all_categories = []
    for filename in findFiles(data_path):
        category = os.path.splitext(os.path.basename(filename))[0]
        all_categories.append(category)
        lines = readLines(filename)
        category_lines[category] = lines
    return category_lines, all_categories

#leerArchivosCarpeta('data/')
path0 = './data/'

path1 = './data/Aurora'
path2 = './data/Giallo'
path3 = './data/Psalmos'

z = leerArchivosCarpeta(path0)
category_lines, all_categoriesz = z
n_categoriesZ = len(all_categoriesz)

a = leerArchivosCarpeta(path1)
category_lines, all_categoriesa = a
# Verificamos que todo se encuentre correctamente, e imprimimos cuantas categorias tienen los datos.
n_categoriesA = len(all_categoriesa)

b = leerArchivosCarpeta(path2)
category_lines, all_categoriesb = b
n_categoriesB = len(all_categoriesb)

c = leerArchivosCarpeta(path3)
category_lines, all_categoriesc = c
n_categoriesC = len(all_categoriesc)


print('Carpeta:' + path0)
print('# Canciones:', n_categoriesZ, all_categoriesz)

print('Carpeta:' + path1)
print('# Canciones:', n_categoriesA, all_categoriesa)

print('Carpeta:' + path2)
print('# Canciones:', n_categoriesB, all_categoriesb)

print('Carpeta:' + path3)
print('# Canciones:', n_categoriesC, all_categoriesc)
# Out:
# Carpeta:./data/
# # Canciones: 2 ['nuestra_afliccion', 'que_pretendes']
# Carpeta:./data/Aurora
# # Canciones: 6 ['aplaudan_en_silencio', 'casanova', 'domingo_de_ceniza', 'nueva_inglaterra', 'posa_y_sonrie', 'tiempo_compartido']
# Carpeta:./data/Giallo
# # Canciones: 13 ['a_tu_merced', 'cantar_de_gesta', 'cerraron_chipinque', 'documentales', 'en_vano', 'la_herida', 'lo_dorado_desvanece', 'nadie_mas_vendra', 'providencia_a_la_izquierda', 'quince_mil_dias', 'quita_esa_cara', 'siempre_vos', 'soy_el_diluvio']
# Carpeta:./data/Psalmos
# # Canciones: 12 ['cara_o_cruz', 'chambelan_(nunca fui)', 'codependientes', 'imposible', 'lamentable', 'la_dama_y_el_moribundo', 'o_discordia', 'padre_nuestro', 'sin_ampersand', 'ssdd', 'tu_dedo_medio', 'violencia']

# %%
'''
Carga los datos de los álbumes en listas separadas y luego combinalos
en una sola lista para su análisis posterior.
'''
def cargarArchivosTextoDesdeDirectorio(directory):
    """
    Carga los archivos .txt desde un directorio especifico y devuelve el contenido del texto y el nombre del archivo.

    Args:
    - directory (str): Ruta al directorio que contiene los archivos .txt.

    Returns:
    - Una lista de tuplas donde cada tupla contiene el contenido del texto y el nombre del archivo.
    """
    all_text_files = glob.glob(os.path.join(directory, '*.txt'))
    data = []
    album = os.path.basename(directory)
    for text_file in all_text_files:
        filename = os.path.basename(text_file)
        with open(text_file, 'r', encoding='utf-8') as file:
            content = file.read()
            data.append((album, filename, content))
    return data

# Directorios de los álbumes
album_directories = ['./data/Psalmos', './data/Giallo', './data/Aurora']

# Lista para almacenar los datos de todos los archivos
all_data = []

# Cargar los archivos de cada álbum y combinarlos en una sola lista
for directory in album_directories:
    album_data = cargarArchivosTextoDesdeDirectorio(directory)
    all_data.extend(album_data)


# Verificar que se hayan cargado los datos correctamente
for album, filename ,content in all_data:
    print(f"Álbum: {album}")
    print(f"Nombre del archivo: {filename}")
    print(f"Contenido del texto:\n{content}\n")
# Out:
# Álbum: Psalmos
# Nombre del archivo: cara_o_cruz.txt
# Contenido del texto:
# Solo en mi cuarto
# Escucho pasos en el corredor
# Sombras a lo largo
# Y de repente solo un resplandor
# Podría ser tu regreso
# La moneda de un peso aquí me dirá si eres tú
# Lo dudo, juguemos cara o cruz uh
# Si es cara es alguien mas
# Quien será que más me da
# Si es cruz uh
# Estoy seguro que eres tú uh
# Si me queda claro
# Una moneda nunca bastará
# Pero que se yo, una flor
# Chance si me alcanzará
# A quien se le entregaría pues no habrá día que tú llegaras
# Sin embargo acá estoy soñando
# Te reto a cara o cruz
# Si es cara nunca más, nunca te arrepentirás
# Si es cruz uh
# Seguiría vivo aun
# Más no sé cuanto mas
# No se cuanto mas
# Juguemos cara o cruz uh
# Si cae cara bastará
# Esta pieza de metal
# Si es cruz uh
# Tú y yo hasta el ataúd
# Tú y yo hasta el ataúd
#
# Álbum: Psalmos
# Nombre del archivo: chambelan_(nunca fui).txt
# Contenido del texto:
# ...

# %% [markdown]
# ### **Generamos un CSV de los Datos Anteriores**

# %%
# Convertimos en csv lo anterior, la primera columna sera el album (carpeta donde se encuentra)
# la segunda columna sera el nombre del archivo y la tercera el contenido del archivo

df = pd.DataFrame(all_data, columns=['Album', 'Nombre_Cancion', 'Letra_Cancion'])
df.to_csv('data.csv', index=False)

# %%
pd.read_csv('data.csv', encoding='utf-8')
# Out:
#       Album                  Nombre_Cancion  \
# 0   Psalmos                 cara_o_cruz.txt
# 1   Psalmos       chambelan_(nunca fui).txt
# 2   Psalmos              codependientes.txt
# 3   Psalmos                   imposible.txt
# 4   Psalmos                  lamentable.txt
# 5   Psalmos      la_dama_y_el_moribundo.txt
# 6   Psalmos                 o_discordia.txt
# 7   Psalmos               padre_nuestro.txt
# 8   Psalmos               sin_ampersand.txt
# 9   Psalmos                        ssdd.txt
# 10  Psalmos               tu_dedo_medio.txt
# 11  Psalmos                   violencia.txt
# 12   Giallo                 a_tu_merced.txt
# 13   Giallo             cantar_de_gesta.txt
# 14   Giallo          cerraron_chipinque.txt
# 15   Giallo                documentales.txt
# 16   Giallo                     en_vano.txt
# 17   Giallo                   la_herida.txt
# 18   Giallo         lo_dorado_desvanece.txt
# 19   Giallo            nadie_mas_vendra.txt
# ...

# %%
canciones_DF = pd.read_csv('data.csv', encoding='utf-8')

# %%
canciones_DF.columns
# Out:
# Index(['Album', 'Nombre_Cancion', 'Letra_Cancion'], dtype='object')

# %% [markdown]
# Todo lo anterior lo guardamos en un archivo CSV para poder cargarlo y usar de mejor manera todo el data set proporcionado
# ya que tuvimos dificultades al tratar de operar el data set de las canciones de José Madero por .txt separados.

# %% [markdown]
# ### 📈 **Vectorización de datos**

# %% [markdown]
# ##### **¿Qué es TfidfVectorizer y por qué es útil en el procesamiento de textos?**
#
# TF-IDF (Term Frequency-Inverse Document Frequency) es un método estadístico utilizado para evaluar la importancia de una palabra (keyword) en un documento, que es parte de una colección. En particular, TF es la frecuencia con la que aparece una palabra en un documento específico, mientras que IDF es el logaritmo de la división entre el número total de documentos en el corpus y el número de documentos en los que aparece el término.
#
# TF-IDF es importante ya que por si solo un modelo no va a poder interpretar cualquier tipo de dato en un formato arbitrario, necesita de la ayuda de una matriz de características como las que nos ofrece TF-IDF para que el modelo pueda aprender de los datos que se le proporcionan.
#
# Algunos aspectos en los cuales es útil utilizar TF-IDF:
#
# 1. *Ponderación de la importancia de las palabras*: Considera tanto la frecuencia de una palabra en un documento (Frecuencia del término) como la rareza de la palabra en toda la colección de documentos (Frecuencia inversa del documento). Esto ayuda a priorizar las palabras que son frecuentes en el documento pero raras en toda la colección, lo que a menudo indica su importancia al describir el contenido del documento.
#
# 2. *Reducción de dimensionalidad*: al representar documentos como vectores TF-IDF, puede reducir la dimensionalidad del espacio del documento y al mismo tiempo preservar información importante. Esto es especialmente útil en tareas como agrupación y clasificación de documentos.
#
# 3. *Manejo de palabras vacías*: palabras comunes como "el", "es", "y" aparecen con frecuencia en los textos, pero generalmente no contienen mucha información. TF-IDF naturalmente disminuye su importancia porque es probable que sean frecuentes en muchos documentos de la colección.
#
# 4. *Personalizable y Flexible*: TF-IDF permite la personalización a través de diferentes variantes y parámetros. Por ejemplo, puede ajustar la forma en que calcula la frecuencia de los términos (recuentos simples, normalización de registros, etc.) o cómo calcula la frecuencia de los documentos (versiones suavizadas, escalado sublineal, etc.), según sus necesidades específicas y las características de su corpus de texto.
#
# 5. *Interpretabilidad*: a diferencia de modelos más complejos como las redes neuronales, TF-IDF es relativamente simple e interpretable. La puntuación TF-IDF de cada término brinda información sobre su importancia dentro de un documento específico y en todo el corpus.

# %% [markdown]
# Utiliza TfidfVectorizer para convertir los textos cargados en una
# matriz de características TF-IDF.
#
# Explica brevemente en tu reporte qué es TF-IDF
# y por qué es util para el procesamiento de textos.

# %%
# Creamos un objeto TfidfVectorizer
vectorizer = TfidfVectorizer()

# Aplicamos el vectorizador a la columna 'Letra_Cancion' 
tfidf_matrix = vectorizer.fit_transform(canciones_DF['Letra_Cancion'])

# Observamos las dimensiones de la matriz TF-IDF
print("Dimensiones de la matriz TF-IDF:", tfidf_matrix.shape)
# Out:
# Dimensiones de la matriz TF-IDF: (31, 1461)

# %% [markdown]
# ### **Aplicación de K-Means**

# %% [markdown]
# Usa una instancia de KMeans() de sklearn.cluster para clasificar textos en k clusters (tú eliges el valor de k).
#
# Justifica la elección del valor que le asignes a k y menciona detalladamente qué representa cada uno en términos de los
# álbumes de José Madero.
#
# **Justificación**
#
# Cada k se asigna a abstractamente a un álbum distinto de José Madero, por ello el número 3, esto con la intención de verificar si existe una relación entre el contenido de las canciones de cada álbum con el clúster al que se le es asignado a cada canción.
#
# Asocia cada archivo con su cluster e imprime los resultados.
#
# ¿Cómo se agruparon los datos y qué diferencia hay con su agrupación original?
#
# **Respuesta**
#
# La agrupación de los datos se ve influenciada por el uso de TF-IDF pues analiza en cada letra de cada canción los términos más frecuentes dentro de su estructura lo que conlleva a que el algorimto de clustering agrupe los datos basándose en los resultados de éste análisis, de tal manera, que si alguna canción comparte términos frecuentes con otra independientemente del álbum al que pertenecen se agrupan dentro del mismo clúster, lo que difiera de la agrupación original que está determinada por un orden específico realizado por el artista (de acuerdo a un tema o similitudes).

# %%
'''
Dado que estamos trabajando con tres álbumes distintos y cada uno tiene un numero diferente de canciones
La k mas adecuada es 3
'''
k = 3

# Crear una instancia de KMeans
kmeans = KMeans(n_clusters=k, random_state=42)

# Aplicar KMeans a la matriz TF-IDF
kmeans.fit(tfidf_matrix)

# Asociar cada cancion con su cluster
canciones_DF['Cluster'] = kmeans.labels_

# Imprimir los resultados
print("Canciones asignadas a cada cluster:")
for i in range(k):
    print(f"\nCluster {i}")
    print(canciones_DF[canciones_DF['Cluster'] == i][['Album', 'Nombre_Cancion']])
    print("Numero de canciones en el cluster:", canciones_DF[canciones_DF['Cluster'] == i].shape[0])
# Out:
# Canciones asignadas a cada cluster:
#
# Cluster 0
#       Album            Nombre_Cancion
# 6   Psalmos           o_discordia.txt
# 7   Psalmos         padre_nuestro.txt
# 11  Psalmos             violencia.txt
# 25   Aurora  aplaudan_en_silencio.txt
# Numero de canciones en el cluster: 4
#
# Cluster 1
#       Album                  Nombre_Cancion
# 1   Psalmos       chambelan_(nunca fui).txt
# 8   Psalmos               sin_ampersand.txt
# 9   Psalmos                        ssdd.txt
# 10  Psalmos               tu_dedo_medio.txt
# 12   Giallo                 a_tu_merced.txt
# 15   Giallo                documentales.txt
# 20   Giallo  providencia_a_la_izquierda.txt
# 22   Giallo              quita_esa_cara.txt
# 23   Giallo                 siempre_vos.txt
# 24   Giallo              soy_el_diluvio.txt
# 29   Aurora               posa_y_sonrie.txt
# Numero de canciones en el cluster: 11
#
# Cluster 2
#       Album              Nombre_Cancion
# 0   Psalmos             cara_o_cruz.txt
# ...

# %% [markdown]
# ### **Visualización de Clusters**
#
# Realiza una reducción de dimensionalidad de la matriz TF-IDF usando TruncatedSVD y representa gráficamente los clusters resultantes.
#
# Describe detalladamente qué representan estos gráficos y cómo se pueden interpretar los resultados.
#
# Cada uno de los integrantes del equipo debe dar su análisis.

# %%
from mpl_toolkits.mplot3d import Axes3D

# Crear un DataFrame para almacenar los resultados originales y el cluster asignado
original_df = pd.DataFrame(tfidf_matrix.toarray(), columns=[f"feature_{i+1}" for i in range(tfidf_matrix.shape[1])])
original_df['Cluster'] = kmeans.labels_

# Graficar los clusters en un espacio 3-D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Asignar ejes y colores por cluster
for cluster, color in zip(original_df['Cluster'].unique(), ['r', 'g', 'b']):
    cluster_points = original_df[original_df['Cluster'] == cluster]
    ax.scatter(cluster_points['feature_1'], cluster_points['feature_2'], cluster_points['feature_3'], c=color, label=f'Cluster {cluster}', alpha=0.2)

# Añadir etiquetas y titulo
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Feature 3')
ax.set_title('Clusters Resultantes antes de la Reduccion de Dimensionalidad')
ax.legend(title='Cluster')

plt.show()

# %%
# Reduccion de dimensionalidad usando TruncatedSVD
svd = TruncatedSVD(n_components=2, random_state=42)
tfidf_matrix_reduced = svd.fit_transform(tfidf_matrix)

# Crear un DataFrame para almacenar los resultados reducidos y el cluster asignado
reduced_df = pd.DataFrame(tfidf_matrix_reduced, columns=['component_1', 'component_2'])
reduced_df['Cluster'] = kmeans.labels_

# Graficar los clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x='component_1', y='component_2', hue='Cluster', data=reduced_df, palette='Set1', legend='full')
plt.title('Clusters Resultantes despues de la Reduccion de Dimensionalidad')
plt.xlabel('Componente 1')
plt.ylabel('Componente 2')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Análisis
#
# <br>
# <a href="https://www.youtube.com/watch?v=B6hc3Cjyys0">
# <img src="https://media.tenor.com/PZyuRn_vn5YAAAAi/triforce.gif" width="40">
# </a>  <strong>Araujo Chávez Mauricio</strong>
# <br>
# <p>En el gráfico anterior podemos observar que los datos se han reducido con dos dimensiones para poder visualizar la clasificación de los datos de manera visual. Dentro de este gráfico existen 3 tipos de puntos con un color diferente asignado lo cual corresponde a cada uno de los clústers creados por Kmeans, además el color es definido por las características de cada uno de los datos. Por ejemplo, dentro del primer clustering se encuentra dentro de las letras el término <em>oh</em>, y eso determina que cada dato sea agrupado dentro de éste clúster, sin importar el álbum al que pertenece y podemos ver que dichos datos están dispersos en una zona superior a los otros dos clústers, por la razón ya expuesta. En los otros casos podemos observar que los datos están en algunas zonas muy juntos y pareciera que deberían estar dentro del mismo clúster, pues tienen una próximidad muy corta, sin embargo, recordemos que el análisis de términos frecuentes es el que define cómo serán agrupados los datos en Kmeans, de tal forma que se agrupan aquellos datos con términos frecuentes en común independientemente de la distancia que tenga cada dato. Esto se debe a que las letras son similares, pero los términos frecuentes varían, dentro del segundo clúster son <em>yo</em> y <em>mi</em>, mientras que en el tercer clúster son palabras que denotan un significa en plural. </p>
# <br>
#
# <br>
# <a href="https://www.youtube.com/watch?v=yeY81At_6L4">
# <img src="https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/5589a669-9b78-41ae-8414-fa7bea390bd1/d1r9m4i-327eb7c3-b511-4eba-90cb-51519befab8a.gif?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..nU8mlYNu3K_xVKIave0nmNYlFJ2Pz8uW_PtrIbO8g80" width="40">
# </a>  <strong>Bonilla Reyes Dafne</strong>
# <br>
#
# Después de analizar los resultados del clustering, notemos que la técnica Kmeans ha sido efectiva para agrupar las canciones en función de sus características. La visualización en dos dimensiones nos permite identificar tres clusters distintos, cada uno con sus propias características distintivas. Es interesante observar cómo las letras de las canciones, especialmente los términos frecuentes como "oh" o "mi", han influido en la formación de estos clusters, mostrando una relación entre las temáticas de las canciones y los clusters a los que pertenecen. Además, la comparación entre la visualización en 3D y la reducción a dos dimensiones ha revelado una distribución más clara de los clusters, resaltando posibles relaciones entre las canciones dentro de cada grupo. Con esto, vemos la importancia de considerar tanto el contenido de las letras como las características musicales en el proceso de clustering para obtener agrupaciones significativas y relevantes.
#
# <br>
# <a href="https://www.youtube.com/watch?v=bqwLVQ7uv1c">
# <img src="https://media.tenor.com/m6cM9lV-doYAAAAi/batman-batman-beyond.gif" width="40">
# </a>  <strong>Castañón Maldonado Carlos Emilio</strong>
#
# Notemos como es que en nuestro primer cluster tuvimos canciones cuya principal caracteristica eran los oh-oh, o los ah-ah ademas de que las canciones agrupadas en este cluster reflejan mucho dolor y arrepentimiento sobre un amor que ya no fue, en el siguiente cluster podemos notar como es que se agruparon las canciones cuya tematica mayoritariamente era la de desamor, vacios emocionales y mayormente depresion (notemos como en este solo tuvimos canciones de Psalmos y Giallo cuya tematica es justo esa), en el ultimo cluster tuvimos canciones de los tres albumes sin embargo la tematica de estas era mas orientada a la fama, dificultades y el progreso personal, es interesante veer como es que la tematica de las canciones puede corresponder a la tematica de otras canciones pero de otro album.
#
# <br>
#
#
# <br>
# <a href="https://www.youtube.com/watch?v=la6rFFSFPhg">
# <img src="https://i.pinimg.com/originals/9c/40/eb/9c40eb371f746929e1cb477da963e7a5.gif" width="40">
# </a>  <strong>Clemente Herrera Karla</strong>
# <br>
#
# El análisis de clustering mediante Kmeans nos creo 3 agrupaciones, las cuales se muestran en ambos grafos, de las canciones basadose en las características de las canciones. Palabras repetidas en los lyrics influyeron en la formación de estos clusters, mostrando una relación entre los temas que tratan las canciones, esto se ve claramente en el cluster 0,  las canciones que pertenecen a este cluster contienen repetida la palabra 'Oh', lo cual influyo para su agrupación. El grafo en 3D y el segundo grafo, en el que se realizó una reducción a dos dimensiones, nos muestra como es la distribución de los clusters de una forma más clara, revelando la 'saturación' que tiene el cluster 2(es el que más canciones tiene) y mostrando que se tienen más canciones con la temática de dificultades y relaciones interpersonales.
#
# <br>
# <a href="https://www.youtube.com/watch?v=tTZ18m4W3gY">
# <img src="https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/3f8e7cb6-257a-4785-a420-51b3ef31892d/dfnemnj-c4089427-4907-4426-b93b-3aec6e05502e.gif?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..4KO7UB3C_kGhJNVi8BPrSWWoFSZ7LO-XAYGcRe2_HL4" width="40">
# </a>  <strong>Mares Cruz Tlacaelel Horacio</strong>
#
# En la primer grafica que es antes de la reducción, se opto por una visualización 3D las características TF-IDF y a su vez tener una mejor idea de como estan distribuidos los clusters (canciones) y en este caso se noto algo, cada grupo de cluster esta representado por un color y hay 3, en este caso hay una sobrecarga o saturación en el cluster 2 de color rojizo mas intenso ya que hay muchos conjuntos en un mismo lugar, lo que nos dio a notar esa pequeña anomalia. Ahora en la otra grafica donde ya se realizo la reducción, podemos ver una mejor distribución de los closters que permite tener una mejor interpretación de como se estan organizando y da una mejor idea de  como estan las relaciones entre las canciones, ademas de que observamos un leve comportamiento similar entre el conjunto verde y el azul, suelen estar cerca entre ellos y posiciones (deben tener alguna relacion de caracteristicas).
#
# <br>
#
#
# <br>
# <a href="https://www.youtube.com/watch?v=kP6_nlTdPgI">
# <img src="https://i.pinimg.com/originals/80/7b/5c/807b5c4b02e765bb4930b7c66662ef4b.gif" width="40">
# </a>  <strong>Navarro Santana Pablo César</strong>
# <br>
# Podemos ver justamente que mediante el Kmeans, los 3 clusters separan las canciones en 3 grupos principales, de tal forma que podemos ver que en cada
# grupo, hay ciertas similitudes en la estructuras de estas canciones, como que en el primer cluster, la mayoria tienen las palabras "Oh" y "Ah"
# repetidas, mientras que en la segunda, lo que mas se repite son palabras haciendo referencia a la primera persona como "Yo", "Quiero", "Dame", etc.
# Es así que podemos ver que podemos interpretar estos clusters mediante como van separando las palabras, y si las palabras pueden llegar a ser "Muy generales" podemos ir descartando o incluso aumentar el tamaño de los clusters, de esta forma, obtendremos información mas especifica y poder interpretarlo de diferente forma, todo esto depende de nuestro gusto al final del dia.

# %% [markdown]
# ### **Nuevos datos**
#
# Carga los archivos que_pretendes.txt y nuestra_afliccion.txt. que
# contienen las letras de las canción Qué pretendes de Bad Bunny y J Balvin, y Nuestra
# Aflicción de PXNDX, respectivamente.
#
# Vuelve a realizar el clustering, esta vez incluyendo estos archivos.
# ¿En cuál álbum se agruparon? ¿A qué crees que se debe esto?
#
#  Justifica ampliamente tu respuesta. Cada uno de los integrantes del equipo debe dar su análisis.
#
# Reflexiona sobre el inciso anterior. ¿Qué ajustes podrías realizar para
# que estas nuevas canciones se clasifiquen correctamente en un clúster diferente?
# Justifica detalladamente tu respuesta e implementa la solución propuesta.
# ¿Lograste los resultados esperados? ¿Por qué?
# Cada uno de los integrantes del equipo debe dar su análisis.

# %%
# Directorios de las canciones que pretendes y nuestra afliccion
album_directori = ['./data/']

# Lista para almacenar los datos de todos los archivos
all_data2 = []

# Cargar los archivos de cada álbum y combinarlos en una sola lista
for directory in album_directori:
    album_data = cargarArchivosTextoDesdeDirectorio(directory)
    all_data2.extend(album_data)


# Verificar que se hayan cargado los datos correctamente
for album, filename ,content in all_data2:
    print(f"Álbum: {album}")
    print(f"Nombre del archivo: {filename}")
    print(f"Contenido del texto:\n{content}\n")
# Out:
# Álbum:
# Nombre del archivo: nuestra_afliccion.txt
# Contenido del texto:
# ¿Cuanto, cuanto se necesita para poder resolver, destruir
# Este dilema que me tortura en las noches, no me
# Deja soñar, amplifica mis temores, simple o cabal?
# Encerré y acabe con mis sueños y la llave arrojé
# ¿Para que los necesito? Solo me causan angustia me hace
# Falta un plan, me hace falta astucia y paz mental
# Entiendo el rechazo del mundo, tu repudio, amor
# Pues igual si me conociera tal vez voltearía mi cara
# Tal vez sentiría lastima, dicen que el amor mancha
# Y ya me ensucié
# Parece, si parece, oh no no, que lo mucho que ofrezco
# No ofrece tanto y por eso, por eso, me afronté y
# Dejaré de ser una carga, pues yo ya no aguanto mas farsas
# No lo puedo evitar sentir que muere mi flama
# Cuando no estás
# Y así cierro un ciclo, amor, necesito un favor, un poco
# Mas de medicina, pues nunca entendí la manera para
# Poder evitar sentir que me rompen las piernas
# Cuando no estás
# ...

# %% [markdown]
# ### **Generamos un CSV de los Datos Anteriores**

# %%
df2 = pd.DataFrame(all_data2, columns=['Album', 'Nombre_Cancion', 'Letra_Cancion'])
df2.to_csv('data2.csv', index=False)

pd.read_csv('data2.csv', encoding='utf-8')
# Out:
#    Album         Nombre_Cancion  \
# 0    NaN  nuestra_afliccion.txt
# 1    NaN      que_pretendes.txt
#
#                                        Letra_Cancion
# 0  ¿Cuanto, cuanto se necesita para poder resolve...
# 1  Uah\nUah, uah\nYeah, yeah, yeah, yeah (uh-uh)\...

# %%
# Ahora realizaremos el clustering con data2.csv para saber en que cluster se clasifica cada cancion
# en los 3 clusters obtenidos anteriormente

# Cargar los datos desde el archivo CSV
canciones_DF2 = pd.read_csv('data2.csv', encoding='utf-8')

# Combinar los nuevos datos con los existentes
canciones_DF3 = pd.concat([canciones_DF, canciones_DF2], ignore_index=True)

# Crear una nueva matriz TF-IDF con las letras actualizadas
tfidf_matrix2 = vectorizer.transform(canciones_DF3['Letra_Cancion'])

# Realizar el clustering nuevamente
kmeans.fit(tfidf_matrix2)

# Asociar cada cancion con su cluster
canciones_DF3['Cluster'] = kmeans.labels_

# Imprimir los resultados
print("Canciones asignadas a cada cluster:")
for i in range(k):
    print(f"\nCluster {i}")
    print(canciones_DF3[canciones_DF3['Cluster'] == i][['Album', 'Nombre_Cancion']])
    print("Numero de canciones en el cluster:", canciones_DF3[canciones_DF3['Cluster'] == i].shape[0])

# Visualizar los resultados

# Reduccion de dimensionalidad usando TruncatedSVD
svd = TruncatedSVD(n_components=2, random_state=42)
tfidf_matrix_reduced2 = svd.fit_transform(tfidf_matrix2)

# Crear un DataFrame para almacenar los resultados reducidos y el cluster asignado
reduced_df2 = pd.DataFrame(tfidf_matrix_reduced2, columns=['component_1', 'component_2'])
reduced_df2['Cluster'] = kmeans.labels_

# Graficar los clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x='component_1', y='component_2', hue='Cluster', data=reduced_df2, palette='Set1', legend='full')
plt.title('Clusters Resultantes despues de la Reduccion de Dimensionalidad')
plt.xlabel('Componente 1')
plt.ylabel('Componente 2')
plt.legend(title='Cluster')

plt.grid(True)
plt.show()
# Out:
# Canciones asignadas a cada cluster:
#
# Cluster 0
#       Album     Nombre_Cancion
# 8   Psalmos  sin_ampersand.txt
# 12   Giallo    a_tu_merced.txt
# Numero de canciones en el cluster: 2
#
# Cluster 1
#       Album                  Nombre_Cancion
# 5   Psalmos      la_dama_y_el_moribundo.txt
# 6   Psalmos                 o_discordia.txt
# 7   Psalmos               padre_nuestro.txt
# 10  Psalmos               tu_dedo_medio.txt
# 11  Psalmos                   violencia.txt
# 16   Giallo                     en_vano.txt
# 17   Giallo                   la_herida.txt
# 20   Giallo  providencia_a_la_izquierda.txt
# 21   Giallo             quince_mil_dias.txt
# 23   Giallo                 siempre_vos.txt
# 24   Giallo              soy_el_diluvio.txt
# 25   Aurora        aplaudan_en_silencio.txt
# 27   Aurora           domingo_de_ceniza.txt
# 30   Aurora           tiempo_compartido.txt
# 32      NaN               que_pretendes.txt
# Numero de canciones en el cluster: 15
#
# Cluster 2
# ...

# %% [markdown]
# ### Análisis
#
# <br>
# <a href="https://www.youtube.com/watch?v=B6hc3Cjyys0">
# <img src="https://media.tenor.com/PZyuRn_vn5YAAAAi/triforce.gif" width="40">
# </a>  <strong>Araujo Chávez Mauricio</strong>
# <br>
# <p>En estos resultados vemos que los nuevos datos modificaron la estructura de cada uno de los clústers, pues ambas canciones modifican el número de términos frecuentes que comparten con otras canciones. Veamos un ejemplo: nuestra aflicción se agrupa dentro del clúster 3 (que se mantiene casi igual que antes de los nuevos datos), sin embargo, esto hace que la canción chambelán se mueva a este clúster, pues los términos frecuentes de éstas son <em>como</em>, <em>nunca</em> y <em>mi</em> haciendo que la claisificación varíe de la anterior. De igual manera Qué pretendes, modifica por completo la estructura del clúster 1, pues ahora contiene canciones con términos plurales, <em>oh</em> y <em>ah</em>, pues la estructura de la canción qué pretendes contiene muchos de éstos elementos. Intuitivamente, podríamos suponer que si cambiasemos el número k por 4 (un hiperparámetro) las canciones se agruparían en un clúster diferente, sin embargo, al realizar el cambio vemos que esto no afecta y los clústers tienen casi los mismos resultados, por lo tanto, para poder lograr que se agrupen en otro clúster podríamos utilizar un preprocesamiento de datos diferentes o limitar el número de características que utiliza TF-IDF para ir variando los resultados hasta obtener el deseado.</p>
# <br>
# Mi canción fav fue Sin ampersand, aunque había una que se llama Plural siendo singular de carmesí y también está buena :3
# <br>
#
# <br>
# <a href="https://www.youtube.com/watch?v=yeY81At_6L4">
# <img src="https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/5589a669-9b78-41ae-8414-fa7bea390bd1/d1r9m4i-327eb7c3-b511-4eba-90cb-51519befab8a.gif?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..nU8mlYNu3K_xVKIave0nmNYlFJ2Pz8uW_PtrIbO8g80" width="40">
# </a>  <strong>Bonilla Reyes Dafne</strong>
# <br>
#
# Después de analizar las nuevas adiciones al conjunto de datos y su impacto en el clustering, se puede observar una modificación significativa en la estructura de los clusters. La inclusión de las canciones "Nuestra Aflicción" de PXNDX y "Que Pretendes" de Bad Bunny y J Balvin ha generado cambios en la distribución de las canciones en los clusters. Por ejemplo, "Nuestra Aflicción" ha influenciado en la reubicación de la canción "Chambelán" en el cluster 3, mientras que "Que Pretendes" ha alterado la composición del cluster 1. Esto resalta la sensibilidad del algoritmo Kmeans a los términos frecuentes presentes en las canciones y cómo estos afectan la agrupación final.
#
# La visualización de los clusters también reveló que las nuevas canciones no solo impactaron su propio agrupamiento, sino que también indujeron cambios en la clasificación de algunas canciones preexistentes. Esto sugiere una dinámica interactiva dentro del proceso de clustering, donde la inclusión de nuevos datos puede desencadenar una reorganización general de las agrupaciones.
#
# Sin embargo, la observación de estas reorganizaciones sugiere una posible limitación en la capacidad del modelo para capturar completamente las diferencias entre las nuevas canciones y las ya existentes en los clusters establecidos previamente. Esto plantea la necesidad de explorar alternativas para mejorar el proceso de clustering, como la consideración de un mayor número de clusters para permitir una mayor especificidad en la agrupación de las canciones. Aunque el objetivo inicial podría no haberse alcanzado completamente debido a las reorganizaciones inesperadas, estas observaciones ofrecen insights valiosos para futuras mejoras en el análisis de clustering de las canciones.
#
# Mi cancion favorita fue cara o cruz :3.
# <br>
# <a href="https://www.youtube.com/watch?v=bqwLVQ7uv1c">
# <img src="https://media.tenor.com/m6cM9lV-doYAAAAi/batman-batman-beyond.gif" width="40">
# </a>  <strong>Castañón Maldonado Carlos Emilio</strong>
#
# En este clustering en el que tuvimos de agregados a Nuestra Afliccion de PXNDX y Que Pretendes de Bad Bunny y J Balvin, podemos notar como es que las canciones de PXNDX y Bad Bunny y J Balvin se agruparon en diferente cluster, ademas de que en el primer cluster tenemos dos canciones especialmente tristes que hablan sobre dos personas que se quieren y se perdieron, pero una de ellas siente un profundo arrepentimiento y quiere regresar con su amor, otra cosa curiosa ademas de este primer cluster es que el siguiente cluster conserva una gran parte de las canciones del anterior analisis pero tambien notamos algunas ausencias como la de chambelan (nunca fui) la cual la agrupo en el siguiente cluster con todas las otras que son mayoitariamente de superacion personal, ademas de que en este segundo cluster se agrupo la de Nuestra Afliccion la cual va muy acorde a la tematica depresiva amorosa de este segundo cluster, en el tercero tuvimos practicamente los mismos resultados de el analisis anterior (salvo algunas canciones que ya no estan en este cluster y se fueron al anterior, o canciones del cluster anterior que terminaron en este), ademas de que en este ahora se encuentra la cancion de Bad Bunny.
#
# Mi cancion favorita fue la de nuestra afliccion.
# <br>
#
# <br>
# <a href="https://www.youtube.com/watch?v=la6rFFSFPhg">
# <img src="https://i.pinimg.com/originals/9c/40/eb/9c40eb371f746929e1cb477da963e7a5.gif" width="40">
# </a>  <strong>Clemente Herrera Karla</strong>
# <br>
#
# Después de agregar "Nuestra Aflicción" de PXNDX y "Que Pretendes" de Bad Bunny y J Balvin se generaron cambios en la estructura de los clusters que ya se tenía, se reubicaron unas canciones, como es el caso de "o discordia" del cluster 0 al cluster 1 y "chambelan (nunca fui)" del cluster 1 al cluster 2, estos cambios en los cluster se debe a que las nuevas canciones modifican el número de frecuencia que tienen unas palabras y como se menciono anteriormente, la frecuencia influye en la construcción del cluster. En el cluster 1 se encuentran canciones que repiten varias veces 'oh' y 'ah', es por esto que "Que Pretendes" se agrupo en este cluster, el cluster 2 conserva casi las mismas canciones que en el ejercicio 4, por lo que conserva la temática de dificultades y relaciones interpersonales, y al tratar está temática "Nuestra Aflicción" es que se agrupo en el cluster 2.
#
# Para que estas nuevas canciones se clasifiquen en un cluster diferente se podría aumentar el número de clusters a 4, de esta forma se podrían encontrar otras características y por ende se organizarían mejor las canciones. Al realizar este cambio se obtiene casi la misma estructura de los cluster, esto muy probablemente porque no se llega a encontrar una característica que identifique a las nuevas canciones, como para que se clasifiquen en un cluster distinto, de todas las canciones violencia estaba muy buena.
#
# <br>
# <a href="https://www.youtube.com/watch?v=tTZ18m4W3gY">
# <img src="https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/3f8e7cb6-257a-4785-a420-51b3ef31892d/dfnemnj-c4089427-4907-4426-b93b-3aec6e05502e.gif?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..4KO7UB3C_kGhJNVi8BPrSWWoFSZ7LO-XAYGcRe2_HL4" width="40">
# </a>  <strong>Mares Cruz Tlacaelel Horacio</strong>
#
# En esta parte vemos que para que_pretendes.txt fue al cluster 2 y nuestra_afliccion.txt al cluster 3, el que los organice en eso lugares se puede deber a que estas nuevas canciones tuvieran posibles similitudes temáticas que tengan entre otras ya establecidas en esos conjuntos previamente, su líricas o palabras clave. Otra cosa que me hicieron notar y fue gracias a la grafica, fue que aparte de organizarse las nuevas canciones, reorganizo algunas canciones que ya pertenecían a un cluster anteriormente, teniendo asi un resultado diferente en la reducción comparado con el punto 4.
#
# Para mejorar esto, algo que se me viene claro a la mente despues de lo que paso con la reorganizacion de las canciones, seria poder mas diferentes separaciones o clusters, pues como se vio, las nuevas canciones pertenician pero a la vez no a la clasificacion que se les dio, de esta manera con mas cantidades de clusters se podria organizar de una manera mas eficiente a las canciones. Ahora en tanto si se logro el objetivo diria que no ya que no se logran por completo los resultados esperados pues cuando se agregaron las nuevas canciones note que el modelo no pudo capturar bien las diferencias entre las nuevas canciones y las existentes en los clusters creando lo que vimos de otra nueva reorganizacion.
#
# Mi cancion favorita fue casanova.
#
# <br>
#
#
# <br>
# <a href="https://www.youtube.com/watch?v=kP6_nlTdPgI">
# <img src="https://i.pinimg.com/originals/80/7b/5c/807b5c4b02e765bb4930b7c66662ef4b.gif" width="40">
# </a>  <strong>Navarro Santana Pablo César</strong>
# <br>
# Podemos observar que la inclusión de estas canciones, llegarón a afectar el ordenamiento original, haciendo que varias canciones pasarán a otro cluster y así
# Esto se debe a que al integrar estas nuevas canciones, En especial la de Bad Bunny, como tiene una estructura muy diferente que las canciones que habiamos estado revisando, esto genera que altere los parametros para clasificar, de tal forma que en cierta forma confundimos al algoritmo.
# Es como si tuvieramos que separar a los alumnos de un grupo de tal forma de los que tengan una calificación mayor al promedio y los que tengan una calificación menor al promedio
# Y vamos acomodandolos y vemos que todos tienen calificaciones que van de 0 a 10, hasta que de repente hay alguién que tiene calificación de 1,000 por un error, entonces al obtener el promedio, vemos que este caso especial, hace que se nos modifiqué la acomodación inicial, ya que si antes el promedio era de 8.5, ahora el promedio puede ser de 400.
# En este caso de las canciones, es algo similar (Sin ser tan drasticos) ya que nos introducé un elemento ajeno a los que estabamos insertando en primer lugar, es así que algunas canciones cambian de grupo inicial.
# Se podría corregir esto de dos formas:
# Al implementar un metodo de verificación o de disonancia para encontrar estos elementos que hacen "Ruido" en la grafica y poder así eliminarlos o hacer lo pertinente.
# Incluir muchos mas datos iniciales, de tal forma que la añadición de este dato erroreo, no haga que cambie la grafica.
#
# Sería de cuestión de en que situación nos encontramos y cual es la que mas nos conviene
#
# Ah, y por ultimo, no he escuchado a Jose Madero y de PXNDX he escuchado un poco, pero el album "Amantes sunt amentes" esta muy bueno.

# %% [markdown]
# ¿Qué ajustes podrías realizar para que estas nuevas canciones se clasifiquen correctamente en un clúster diferente?
#
# Como resultado de lo anterior vamos a probar con una K=5 para que todas las canciones que traten de depresión,vacío emocional,
# superación personal, progreso personal y las que tienen como tema las dificultades ligadas a la fama, puedan tener cada una un cluster diferente
# sin que influya nuestro numero de albums o canciones asociadas.

# %%
# Actualizar el valor de k
k = 5

# Crear una instancia de KMeans
kmeans = KMeans(n_clusters=k, random_state=42)

# Cargar los datos desde el archivo CSV
canciones_DF2 = pd.read_csv('data2.csv', encoding='utf-8')

# Combinar los nuevos datos con los existentes
canciones_DF3 = pd.concat([canciones_DF, canciones_DF2], ignore_index=True)

# Crear una nueva matriz TF-IDF con las letras actualizadas
tfidf_matrix2 = vectorizer.transform(canciones_DF3['Letra_Cancion'])

# Realizar el clustering nuevamente
kmeans.fit(tfidf_matrix2)

# Asociar cada cancion con su cluster
canciones_DF3['Cluster'] = kmeans.labels_

# Imprimir los resultados
print("Canciones asignadas a cada cluster:")
for i in range(k):
    print(f"\nCluster {i}")
    print(canciones_DF3[canciones_DF3['Cluster'] == i][['Album', 'Nombre_Cancion']])
    print("Numero de canciones en el cluster:", canciones_DF3[canciones_DF3['Cluster'] == i].shape[0])

# Visualizar los resultados

# Reduccion de dimensionalidad usando TruncatedSVD
svd = TruncatedSVD(n_components=2, random_state=42)
tfidf_matrix_reduced2 = svd.fit_transform(tfidf_matrix2)

# Crear un DataFrame para almacenar los resultados reducidos y el cluster asignado
reduced_df2 = pd.DataFrame(tfidf_matrix_reduced2, columns=['component_1', 'component_2'])
reduced_df2['Cluster'] = kmeans.labels_

# Graficar los clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x='component_1', y='component_2', hue='Cluster', data=reduced_df2, palette='Set1', legend='full')
plt.title('Clusters Resultantes despues de la Reduccion de Dimensionalidad')
plt.xlabel('Componente 1')
plt.ylabel('Componente 2')
plt.legend(title='Cluster')
plt.grid(True)
plt.show()
# Out:
# Canciones asignadas a cada cluster:
#
# Cluster 0
#      Album   Nombre_Cancion
# 12  Giallo  a_tu_merced.txt
# Numero de canciones en el cluster: 1
#
# Cluster 1
#       Album                  Nombre_Cancion
# 6   Psalmos                 o_discordia.txt
# 7   Psalmos               padre_nuestro.txt
# 11  Psalmos                   violencia.txt
# 16   Giallo                     en_vano.txt
# 17   Giallo                   la_herida.txt
# 20   Giallo  providencia_a_la_izquierda.txt
# 21   Giallo             quince_mil_dias.txt
# 24   Giallo              soy_el_diluvio.txt
# 25   Aurora        aplaudan_en_silencio.txt
# 27   Aurora           domingo_de_ceniza.txt
# 30   Aurora           tiempo_compartido.txt
# Numero de canciones en el cluster: 11
#
# Cluster 2
#       Album             Nombre_Cancion
# 1   Psalmos  chambelan_(nunca fui).txt
# 2   Psalmos         codependientes.txt
# 4   Psalmos             lamentable.txt
# 14   Giallo     cerraron_chipinque.txt
# ...

# %% [markdown]
# ### Análisis
#
# <br>
# <a href="https://www.youtube.com/watch?v=B6hc3Cjyys0">
# <img src="https://media.tenor.com/PZyuRn_vn5YAAAAi/triforce.gif" width="40">
# </a>  <strong>Araujo Chávez Mauricio</strong>
# <br>
# <p>En
#
#  </p>
# <br>
#
# <br>
# <a href="https://www.youtube.com/watch?v=yeY81At_6L4">
# <img src="https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/5589a669-9b78-41ae-8414-fa7bea390bd1/d1r9m4i-327eb7c3-b511-4eba-90cb-51519befab8a.gif?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..nU8mlYNu3K_xVKIave0nmNYlFJ2Pz8uW_PtrIbO8g80" width="40">
# </a>  <strong>Bonilla Reyes Dafne</strong>
# <br>
#
# Como aumentamos el numero de clusters podemos notar claramente como es que los k-means se ajustaron de mejor forma a la nueva cantidad de clusters, ya que al tener una mayor diversidad de clusters podemos explotar mejor las caracteristicas que comparten estos grupos de canciones.
#
# <br>
# <a href="https://www.youtube.com/watch?v=bqwLVQ7uv1c">
# <img src="https://media.tenor.com/m6cM9lV-doYAAAAi/batman-batman-beyond.gif" width="40">
# </a>  <strong>Castañón Maldonado Carlos Emilio</strong>
#
# Como podemos notar tenemos una mejor clasificación de las canciones, ahora cada una de las canciones que tratan de depresión,vacío emocional,
# superación personal, progreso personal y las que tienen como tema las dificultades ligadas a la fama, tienen su propio cluster y esto podemos verificarlo con el cluster 4 en el cual todas las canciones en su mayoria tienen la tematica de nuestra afliccion.
# <br>
#
#
# <br>
# <a href="https://www.youtube.com/watch?v=la6rFFSFPhg">
# <img src="https://i.pinimg.com/originals/9c/40/eb/9c40eb371f746929e1cb477da963e7a5.gif" width="40">
# </a>  <strong>Clemente Herrera Karla</strong>
# <br>
#
# E
#
# <br>
# <a href="https://www.youtube.com/watch?v=tTZ18m4W3gY">
# <img src="https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/3f8e7cb6-257a-4785-a420-51b3ef31892d/dfnemnj-c4089427-4907-4426-b93b-3aec6e05502e.gif?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..4KO7UB3C_kGhJNVi8BPrSWWoFSZ7LO-XAYGcRe2_HL4" width="40">
# </a>  <strong>Mares Cruz Tlacaelel Horacio</strong>
#
# Al tener un gran numero de canciones pudimos notar en el analisis anterior que al agregar las nuevas canciones, los clusters empezaron a modificarse claramente por lo que aumentar el numero de clusters trajo una gran mejora en la visualizacion y analisis ya que ahora podemos analizar y observar mejor como es que en por ejemplo, el cluster 2 se asignaron la mayoria de canciones relacionadas a la superacion y progreso personal.
#
# <br>
#
#
# <br>
# <a href="https://www.youtube.com/watch?v=kP6_nlTdPgI">
# <img src="https://i.pinimg.com/originals/80/7b/5c/807b5c4b02e765bb4930b7c66662ef4b.gif" width="40">
# </a>  <strong>Navarro Santana Pablo César</strong>
#
# Como lo dicho anteriormente, podemos notar como al tener estos 5 cluster podemos notar como es que caracteristicas como las de el cluster numero 1
# tiene mayor dimencionalidad y se alejan de los demas puntos ademas de que los clusters visualizados en la parte inferior se pueden distinguir mejor.
#
# <br>
