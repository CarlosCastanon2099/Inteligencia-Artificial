# %% [markdown]
# # 👾 **Práctica 06: Redes Bayesianas** 📐
# ----
#
# ## <b>T</b><b>e</b><b>a</b><b>m</b>: <font color='red'><b>S</b></font><b>ocios</b> <font color='blue'><b>I</b></font><b>nteligentemente</b> <font color='green'><b>A</b></font><b>rtificiales</b> (<font color='red'><b>S</b></font>.<font color='blue'><b>I</b></font>.<font color='green'><b>A</b></font>)
#
# 🔵</font> Araujo Chávez Mauricio
#
# 🔵</font> Bonilla Reyes Dafne
#
# 🔵</font> Castañón Maldonado Carlos Emilio
#
# 🔵</font> Clemente Herrera Karla
#
# 🔵</font> Mares Cruz Tlacaelel Horacio
#
# 🔵</font> Navarro Santana Pablo César

# %% [markdown]
# ## 📏 **Fundamentos de Redes Bayesianas**
# ---
#
# - ### <span style="color:#17FC3F">**Pregunta 1**</span>
#
#     #### 📝 **Investiga y redacta un breve resumen sobre qué son las redes bayesianas y para qué se utilizan.**
#
#     Una **red bayesiana** es un gráfico en el que los nodos representan entidades como moléculas o genes. Los nodos que interactúan están conectados por bordes en la dirección de influencia; la arista $A \to B$ implica que $A$ (el padre) tiene un efecto sobre $B$ (el hijo). En general, una red bayesiana es un gráfico acíclico dirigido; es decir, no se permiten ciclos. Es importante destacar que cada nodo tiene probabilidades adjuntas que definen la posibilidad de encontrar el nodo en un estado determinado. Las probabilidades condicionales se utilizan si el estado de un nodo depende del estado de otro. Estas dependencias se propagan a través de la red e influyen en las probabilidades de otros nodos, que se actualizan a medida que hay nueva información disponible sobre los nodos. Por tanto, las redes bayesianas también se denominan **modelos causales probabilísticos**.
#
#     Las redes bayesianas se utilizan en una variedad de campos para modelar la incertidumbre y tomar decisiones bajo esta. Algunas de las aplicaciones comunes incluyen: diagnóstico médico, análisis de riesgos, reconocimiento de patrones. ,odelado de sistemas expertos o sistemas de recomendación.
#
#     Un ejemplo de esto podría ser un analista de un banco que quiere poder predecir clientes o clientes potenciales, con posibilidades de impago de sus créditos. Para ellos, puede utilizar un modelo de red bayesiana para identificar las características de los clientes con más posibilidades de impago y generar varios tipos diferentes de modelo para establecer el mejor método para predecir los clientes con más posibilidades de impago.
#
# ---
#
# - ### <span style="color:#17FC3F">**Pregunta 2**</span>
#
#     #### ➗ **Explica la diferencia entre probabilidad condicional e independencia condicional, incluyendo ejemplos claros de cada uno.**
#
#     ##### <span style="color:#0082F5">**Probabilidad Condicional**</span>
#
#     La **probabilidad condicional** se refiere a la probabilidad de que ocurra un evento dado que otro evento ya ha ocurrido. Se denota como $P(A | B)$ que significa la probabilidad de que ocurra el evento $A$ dado que el evento $B$.
#
#     Por lo tanto, podemos decir que la **fórmula para calcular la probabilidad condicional** es: $P(A | B) = \frac{P(A \cap B)}{P(B)}$
#
#     > **Ejemplo:**
#     >
#     > - Calcular la probabilidad de enfermedad dado un resultado de prueba:
#     >
#     >   Supongamos que estamos interesados en la probabilidad de que una persona esté enferma $(E)$ dado que el resultado de una prueba $(T)$ es positivo. La probabilidad condicional en este caso sería $P(E|T)$, es decir, la probabilidad de que la persona esté enferma dado que la prueba dio positivo. Esta probabilidad puede ser diferente de la probabilidad de estar enfermo sin tener en cuenta el resultado de la prueba.
#     >
#     >   Entonces, tendremos la siguiente fórmula: $P(E|T) = \frac{P(E \cap T)}{P(T)}$
#
#     ##### <span style="color:#F5CB0F">****Independencia Condicional****</span>
#
#     La **independencia condicional** ocurre cuando la ocurrencia de un evento no afecta la probabilidad de otro evento. Formalmente, dos eventos $A$ y $B$ son independientes condicionalmente si la probabilidad de que ocurra $A$ dado que $B$ ya ha ocurrido es la misma que la probabilidad de que ocurra $A$ en general.
#
#     Por lo tanto, podemos decir que la **la expresión matemática de la independencia condicional** es: $P(A|B) = P(A)$
#
#     > **Ejemplo:**
#     >
#     > - Calcular la independencia Condicional de un lanzamiento de dos monedas:
#     >
#     >    Supongamos que estamos lanzando dos monedas. Los eventos $A$ y $B$ podrían ser "la primera moneda da cara" y "la segunda moneda da cara", respectivamente. Si las dos monedas están justas (es decir, la probabilidad de obtener cara en cada lanzamiento es $\frac{1}{2}$ entonces la ocurrencia de que la primera moneda muestre cara no afecta la probabilidad de que la segunda moneda muestre cara. Por lo tanto, en este caso, los eventos $A$ y $B$ son independientes condicionalmente,
#     >
#     >    Entonces, podemos denotar a este evento como $P(A|B) = P(A) = \frac{1}{2}$
#
# ---
#
# - ### <span style="color:#17FC3F">**Pregunta 3**</span>
#
#     #### 📐 **Describe cómo se representa matemáticamente una red bayesiana y el significado de los nodos y aristas en cada representación.**
#
#     Una **red bayesiana** es un modelo matemático para representar relaciones causales entre variables aleatorias mediante el uso de probabilidades condicionales. En el contexto de una red bayesiana, asumimos que existe un gráfico acíclico dirigido, denotado por $G$, como una relación entre variables aleatorias. En la estimación de redes genéticas basada en redes bayesianas, un gen se considera una variable aleatoria y se muestra como un nodo. Sea $X_i  $ una variable aleatoria discreta que toma un valor de $\{u_1,… , u_m\}$, si hay una arista dirigida $e_{ij}$ de $X_i$ a $X_j$, llamamos a $X_i$ padre de $X_j$, por lo que podemos notar que las aristas representan una relación causal.
#
#     Además, definimos $Pa(X_i) \subseteq \{X1, …, X_p\}$ como el conjunto de padres de $X_i$ en $G$. En $G$, la variable aleatoria $X_i$ sólo depende de sus padres directos $Pa(X_i)$ y es independiente de otros variables (es decir, esto ofrece la propiedad de Markov de primer orden a la relación entre variables descrita por $G$). Usando G y su propiedad de Markov, la probabilidad conjunta de todas las variables aleatorias se puede descomponer como el producto de probabilidades condicionales:
#
#     $P(X_i, ..., X_p) = \prod_{j = 1}^{p} P(X_j \mid Pa (X_j))$
#
#     Como $X_j$ es una variable discreta, las probabilidades $\vartheta_{jkl} = P(X_j = u_k \mid Pa(X_j) = u_{jl}) (j = 1, …, p; k = 1, …, m; l = 1, …, m \mid Pa (X_i)|)$ son parámetros, donde $u_{jl}$ es la l-ésima entrada de la tabla de estados de los padres de $X_j$ y $|Pa(X_j)|$ es el número de padres de $X_j$.
#
#     Por lo tanto, las probabilidades condicionales $P(X_j \mid Pa(X_j))$ describen las relaciones padre-hijo y pueden verse como una extensión de los modelos deterministas, como las redes booleanas.
#
# #### 📚 **Recursos Utilizados**
#
# - [Bayesian Network Mathematic Definition](https://www.sciencedirect.com/topics/mathematics/bayesian-network)
# - [Bayesian Network Examples](https://www.ibm.com/docs/es/spss-modeler/saas?topic=models-bayesian-network-node)
# - [Conditional Probability](https://www.investopedia.com/terms/c/conditional_probability.asp)
# - [Conditional Independence](https://www.probabilitycourse.com/chapter1/1_4_4_conditional_independence.php)

# %% [markdown]
# ### 👾 **Implementación de Redes Bayesianas con pgmpy**

# %% [markdown]
# Importamos las bibliotecas necesarias y establecemos las conexiones de los nodos:
# - **H**: Horas de trabajo
# - **B**: Balance trabajo-vida
# - **S**: Satisfacción laboral

# %%
#usar !pip install pgmpy
from pgmpy.models import BayesianNetwork
from pgmpy.factors.discrete import TabularCPD

# Se define la red bayesiana
modelo = BayesianNetwork([('B', 'S'), ('H', 'B')])

# %% [markdown]
# Creamos las tablas de probabilidad condicional para cada uno de los nodos descritos anteriormente. Y las imprimos para poder visualizar de una manera gráfica y legible su estructura.

# %%
cpd_h = TabularCPD(variable='H',
                   variable_card=3, values=[[0.24], [0.72], [0.04]], #Probabilidades
                   state_names={'H': ['Largas', 'Moderadas', 'Cortas']})

cpd_b = TabularCPD(variable='B', variable_card=2,
                      values=[[0.13, 0.35, 0.72], #Probabilidades
                              [0.87, 0.65, 0.28]],
                      evidence=['H'],
                      evidence_card=[3],
                      state_names={'B': ['Equilibrado', 'No equilibrado'],
                                   'H': ['Largas', 'Moderadas', 'Cortas']})

cpd_s = TabularCPD(variable='S', variable_card=3,
                      values=[[0.37, 0.02], #Probabilidades
                              [0.49, 0.29],
                              [0.14, 0.69]],
                      evidence=['B'],
                      evidence_card=[2],
                      state_names={'S': ['Satisfecho', 'Neutral', 'Insatisfecho'],
                                   'B': ['Equilibrado', 'No equilibrado']})

print("Tabla de probabilidad condicional para las horas de trabajo")
print(cpd_h)
print()
print("Tabla de probabilidad condicional para el balance trabajo-vida")
print(cpd_b)
print()
print("Tabla de probabilidad condicional para la satsifacción laboral")
print(cpd_s)
print()

# %% [markdown]
# Posteriormente se añaden las tablas de probabilidad condicional a la red bayesiana y se verifica que el modelo sea válido. Esto es cierto, si y sólo si, la suma de las probabilidades de cada tabla sea igual a 1.

# %%
# Agrega tablas de probabilidad condicional a la red bayesiana
modelo.add_cpds(cpd_h)
modelo.add_cpds(cpd_b)
modelo.add_cpds(cpd_s)

# verifica que la suma de las tablas sea 1
if modelo.check_model:
    print('La red bayesiana es válida')

# %% [markdown]
# Ahora creamos una instancia de la clase VariableElimination que nos permite realizar predicciones con la red bayesiana construida anteriormente y verificamos las probabilidades de satsisfacción dado que las horas de trabajo sean moderadas y el balance trabajo-vida es equilibrado.

# %%
from pgmpy.inference import VariableElimination

inferencia = VariableElimination(modelo)
# Obtiene probabilidades de la variable S cuando tiene horas de trabajo moderadas y un balance trabajo-vida equilibrado
probabilidades_s = inferencia.query(variables = ['S'], evidence = {'B': 'Equilibrado', 'H': 'Moderadas'})
print()
print("Tabla de probabilidades de satisfacción laboral con condiciones dadas")
print(probabilidades_s)

# %% [markdown]
# ---

# %% [markdown]
# ### ⚙️ **Ajuste de probabilidades**
#
# Tomemos en cuenta la siguiente situación dentro de nuestra red bayesiana
# - El balance vida-trabajo se considera más balanceado cuando se trabajan horas cortas.
#
# Y lo cambiaremos por
#
# - El balance vida-trabajo se considera más balanceado cuando se trabajan horas moderadas.
#
# Implementemos el cambio dentro del código.

# %%
# Modificamos dicha probabilidad
cpd_s = TabularCPD(variable='S', variable_card=3,
                      values=[[0.67, 0.02], #Probabilidades
                              [0.26, 0.69],
                              [0.07, 0.29]],
                      evidence=['B'],
                      evidence_card=[2],
                      state_names={'S': ['Satisfecho', 'Neutral', 'Insatisfecho'],
                                   'B': ['Equilibrado', 'No equilibrado']})

# Reestablecemos nuestro modelo
modelo = BayesianNetwork([('B', 'S'), ('H', 'B')])

#Agregamos las tablas de probabilidad condicional
modelo.add_cpds(cpd_h)
modelo.add_cpds(cpd_b)
modelo.add_cpds(cpd_s)

# verifica que la suma de las tablas sea 1
if modelo.check_model:
    print('La red bayesiana es válida')

inferencia = VariableElimination(modelo)
# Obtiene probabilidades de la variable S cuando tiene horas de trabajo moderadas y un balance trabajo-vida no equilibrado
probabilidades_s = inferencia.query(variables = ['S'], evidence = {'B': 'Equilibrado', 'H': 'Moderadas'})
print()
print("Tabla de probabilidades de satisfacción laboral con condiciones dadas")
print(probabilidades_s)

# %% [markdown]
# ---
# ### 📄 **Análisis y oportunidades de mejora**
#
# - ## **Análisis del punto 2**
# Utilicemos los resultados de satisfacción obtenidos con las tablas de probabilidad condicional originales que se muestran en la siguiente imagen:
#
# <p align="center">
#   <img src="./img/resultado1.png" alt="Resultado punto 2">
# </p>
#
# De esta manera podemos observar que la población se siente neutral ante el modelo de la red bayesiana, pues las horas de trabajo influyen directamente en la decisión, pues la inclinación está dada hacia trabajar un menor número de horas, sin embargo, esto no es posible pues las horas moderadas tienen mayor probabilidad de ser elegidas.
#
# - ## **Análisis del punto 3**
# Utilicemos los resultados de satisfacción obtenidos con las tablas de probabilidad condicional tras realizar una alteración en las probabilidades que se muestran en la siguiente imagen:
#
# <p align="center">
#   <img src="./img/resultado2.png" alt="Resultado punto 3">
# </p>
#
# La elección de modificar las probabilidades es para denotar que efectivamente bajo el modelo los trabajadores tienen una aceptación de trabajar horas moderadas y se realizó con la intención de modelar un poco la situación actual del país donde las jornadas son de 8 horas al día (Que claramente no son horas cortas, pero es lo aceptable). De esta manera, se considera que la población obtiene un balance equilibrado si se trabaja únicamente las horas que por ley están establecidas y, aquellos con dicha de trabajar menos horas, disminuirán porcentaje dado que la población dentro de este rubro es menor.
#
# - ## **Oportunidades de mejora**
#
#   - **Adición de un nodo salario**: el salario obtenido por la horas laboradas, pues es bien sabido que el salario influye mucho en el balance de la vida-trabajo, todo queremos un sueldo justo por el trabajo que realizamos. Y sería un punto interesante, pues podría existir la situación de trabajar horas cortas, pero recibir un sueldo mínimo y está claro que esto no implicaría directamente que la satisfacción laboral va por buen camino, por otro lado, si se trabajan horas moderadas por un sueldo decente la satisfacción podría aumentar significativamente.
#
#   - **Adición de un nodo transporte**: si bien la red modela el balance con los elementos principales, uno de los factores más comúnes por los cuales un trabajador no lleva un balance vida-trabajo es por su lugar de residencia y el tiempo que invierte para trasladarse desde su hogar hasta su destino de trabajo. Por ejemplo, si bien en la Ciudad de México existe un sistema de movilidad bastante grande, es bien sabido que los traslados pueden ser largos (de hasta más de 2 horas) para cruzar dos puntos dentro de la ciudad y esto impacta directamente en la vida de los trabajadores fuera del horario laboral.

# %% [markdown]
# ----
#
# ### 📑 **Avance de la Práctica**
#
# <div>
#   <input type="checkbox" id="check1" name="check1">
#   <label for="check1">Fundamentos de Redes Bayesianas</label>
#   <ul>
#     <li>
#       <input type="checkbox" id="subcheck1" name="subcheck1">
#       <label for="subcheck1">Investigación sobre Redes Bayesianas</label>
#     </li>
#     <li>
#       <input type="checkbox" id="subcheck2" name="subcheck2">
#       <label for="subcheck2">Diferencia entre Probabilidad Condicional e Independencia Condicional</label>
#     </li>
#     <li>
#       <input type="checkbox" id="subcheck2" name="subcheck2">
#       <label for="subcheck2">Representación Matemática de una Red Bayesiana</label>
#     </li>
#   </ul>
# </div>
#
# <div>
#   <input type="checkbox" id="check1" name="check1">
#   <label for="check1">Implementación de Redes Bayesianas con pgmpy</label>
#   <ul>
#     <li>
#       <input type="checkbox" id="subcheck1" name="subcheck1">
#       <label for="subcheck1">Instalar la Biblioteca pgmpy</label>
#     </li>
#     <li>
#       <input type="checkbox" id="subcheck2" name="subcheck2">
#       <label for="subcheck2">Crer una Red Bayesiana</label>
#     </li>
#     <li>
#       <input type="checkbox" id="subcheck2" name="subcheck2">
#       <label for="subcheck2">Tablas de Probabilidad Condicional</label>
#     </li>
#     <li>
#       <input type="checkbox" id="subcheck2" name="subcheck2">
#       <label for="subcheck2">Calcular la Probabilidad de Estar Satisfecho</label>
#     </li>
#   </ul>
# </div>
#
# <div>
#   <input type="checkbox" id="check1" name="check1">
#   <label for="check1">Análisis e Interpretación de Resultados UwU</label>
#   <ul>
#     <li>
#       <input type="checkbox" id="subcheck1" name="subcheck1">
#       <label for="subcheck1">Explica los Resultados Obtenidos en la Parte 2</label>
#     </li>
#     <li>
#       <input type="checkbox" id="subcheck2" name="subcheck2">
#       <label for="subcheck2">Ajusta las Probabilidades de las Tablas</label>
#     </li>
#     <li>
#       <input type="checkbox" id="subcheck2" name="subcheck2">
#       <label for="subcheck2">Plantea una Mejora de la Red Bayesiana Creada</label>
#     </li>
#   </ul>
# </div>
#
# ### ✅ **Entregables**
#
# <div>
#   <input type="checkbox" id="check1" name="check1">
#   <label for="check1">Código fuente del proyecto en un archivo .ipynb.</label>
# </div>
#
# <div>
#   <input type="checkbox" name="check1">
#   <label for="check1">Reporte en donde se explique la implementación, la experimentación y el análisis de los resultados.</label>
# </div>
