# %% [markdown]
# # 👾 **Práctica 06: Redes Bayesianas** 📐
# ----
#
# ## <b>T</b><b>e</b><b>a</b><b>m</b>: <font color='red'><b>S</b></font><b>ocios</b> <font color='blue'><b>I</b></font><b>nteligentemente</b> <font color='green'><b>A</b></font><b>rtificiales</b> (<font color='red'><b>S</b></font>.<font color='blue'><b>I</b></font>.<font color='green'><b>A</b></font>)
#
# 🔵</font> Araujo Chávez Mauricio
#
# 🔵</font> Bonilla Reyes Dafne
#
# 🔵</font> Castañón Maldonado Carlos Emilio
#
# 🔵</font> Clemente Herrera Karla
#
# 🔵</font> Mares Cruz Tlacaelel Horacio D: XD
#
# 🔵</font> Navarro Santana Pablo César
#
# ----
#
# <div align="center">
#   <a href="https://www.youtube.com/watch?v=YRvOePz2OqQ">
#     <img src="https://media2.giphy.com/media/v1.Y2lkPTc5MGI3NjExcmZvamMxbG80aXB1NmhwaHZkdWtoZXE5aGpxNTlhdG5qZWkzY2ZyZSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/aFwLvWSsmeguT3OdnH/giphy.gif" alt="gif" width="700" height="400">
#   </a>
# </div>
#
# ----

# %% [markdown]
# ### 📏 **Fundamentos de Redes Bayesianas**
#
# ##### 1. 📝 Investiga y redacta un breve resumen (máximo una cuartilla) sobre qué son las redes bayesianas y para qué se utilizan.
#
# Una red bayesiana es un gráfico en el que los nodos representan entidades como moléculas o genes. Los nodos que interactúan están conectados por bordes en la dirección de influencia; la arista A→B implica que A (el padre) tiene un efecto sobre B (el hijo). En general, una red bayesiana es un gráfico acíclico dirigido; no se permiten ciclos. Es importante destacar que cada nodo tiene probabilidades adjuntas que definen la posibilidad de encontrar el nodo en un estado determinado. Las probabilidades condicionales se utilizan si el estado de un nodo depende del estado de otro. Estas dependencias se propagan a través de la red e influyen en las probabilidades de otros nodos, que se actualizan a medida que hay nueva información disponible sobre los nodos. Por tanto, las redes bayesianas también se denominan modelos causales probabilísticos.
#
# Los nodos con variables continuas se parametrizan mediante funciones de probabilidad y los de variables discretas mediante tablas de probabilidad. Por ejemplo, considere la red simple de dos nodos A→B donde A y B son variables binarias con dos estados (N o Y). La tabla en el nodo A contendría la probabilidad marginal P(A = Y). Para simplificar, usaremos "A" para significar A = Y y "a" para significar A = N, de modo que P(A = Y) y P(A = N) se puedan escribir más brevemente como P(A) y P(a), respectivamente. Por complementariedad, P(a) = 1 – P(A). En el nodo B tendríamos las probabilidades condicionales P(B|A) y P(Bla) que definen cómo el estado de B depende del estado de A. La tabla de probabilidad condicional (CPT) se puede completar usando complementariedad: P(b |A) = 1 – P(B|A) y P(b|a) = 1 – P(B|a). Por lo tanto, la tabla marginal para A enumera todos los estados posibles para A, y el CPT enumera todas las combinaciones de estados posibles de A y B. Una vez que se construye la red y se especifican las probabilidades, se utiliza el teorema de Bayes para propagar la probabilidad a través del modelo.
#
# ##### 2. ➗ Explica la diferencia entre probabilidad condicional e independencia condicional, incliyendo ejemplos claros de cada uno.
#
# - **Probabilidad Condicional**
#
#     La probabilidad condicional se refiere a la probabilidad de que ocurra un evento dado que otro evento ya ha ocurrido. Se denota como P(A|B)  que significa la probabilidad de que ocurra el evento A dado que el evento B.
#
#     Formula de probabilidad condicional:
#     $P(A|B) = \frac{P(A \cap B)}{P(B)} $
#
#     - **Ejemplo 1:**
#
#         Probabilidad de Enfermedad dado Resultado de Prueba:
#
#         Supongamos que estamos interesados en la probabilidad de que una persona esté enferma (E) dado que el resultado de una prueba (T) es positivo. La probabilidad condicional en este caso sería P(E|T), es decir, la probabilidad de que la persona esté enferma dado que la prueba dio positivo. Esta probabilidad puede ser diferente de la probabilidad de estar enfermo sin tener en cuenta el resultado de la prueba.
#
#         $P(E|T) = P(T|E)*P(E) / P(T)$
#
#
# ----
#
# - **Independencia Condicional**
#
#     La independencia condicional ocurre cuando la ocurrencia de un evento no afecta la probabilidad de otro evento. Formalmente, dos eventos
#     A y B son independientes condicionalmente si la probabilidad de que ocurra A dado que B ya ha ocurrido es la misma que la probabilidad de que ocurra A en general. En términos matemáticos, esto se expresa como:
#
#     Formula de independencia condicional:
#     $P(A|B) = P(A)$
#
#     - **Ejemplo 1:**
#
#         Independencia Condicional lanzando dos monedas:
#
#         Supongamos que estamos lanzando dos monedas. Los eventos A y B podrían ser "la primera moneda muestra cara" y "la segunda moneda muestra cara", respectivamente. Si las dos monedas están justas (es decir, la probabilidad de obtener cara en cada lanzamiento es $\frac{1}{2}$ ) entonces la ocurrencia de que la primera moneda muestre cara no afecta la probabilidad de que la segunda moneda muestre cara. Por lo tanto, en este caso, los eventos A y son independientes condicionalmente, y
#
#         $P(A|B) = P(A) = \frac{1}{2}$
#
#
# ##### 3. 📐 Describe cómo se representa matemáticamente una red bayesiana y el significado de los nodos y aristas en cada representación.
#
# Una red bayesiana es un modelo matemático para representar relaciones causales entre variables aleatorias mediante el uso de probabilidades condicionales. En el contexto de una red bayesiana, asumimos que existe un gráfico acíclico dirigido (DAG), denotado por G, como una relación entre variables aleatorias. En la estimación de redes genéticas basada en redes bayesianas, un gen se considera una variable aleatoria y se muestra como un nodo. Sea Xi (i = 1,…, p) una variable aleatoria discreta que toma un valor de {u1,…, um}. Si hay una arista dirigida eij de Xi a Xj, llamamos a Xi padre de Xj.
#
# Además, definimos Pa(Xi) ⊆ {X1, …, Xp} como el conjunto de padres de Xi en G. En el DAG G, la variable aleatoria Xi sólo depende de sus padres directos Pa(Xi) y es independiente de otros variables (es decir, esto ofrece la propiedad de Markov de primer orden a la relación entre variables descrita por G). Usando el DAG G y su propiedad de Markov, la probabilidad conjunta de todas las variables aleatorias se puede descomponer como el producto de probabilidades condicionales:
#
# Como Xj es una variable discreta, las probabilidades θjkl = P(Xj = uk|Pa(Xj) = ujl) (j = 1, …, p; k = 1, …, m; l = 1, …, m|Pa (Xi)|) son parámetros, donde ujl es la l-ésima entrada de la tabla de estados de los padres de Xj y |Pa(Xj)| es el número de padres de Xj. Por ejemplo, para |Pa(Xj)| = 2 tenemos uj1 = (u1, u1), uj2 = (u1, u2), y así sucesivamente. En este caso, podemos suponer que Xj |Pa(Xj) = ujl sigue la distribución multinomial con probabilidades θj1l,…, θjml (Friedman y Goldszmidt 1998).
#
# Las probabilidades condicionales P(Xj |Pa(Xj)) describen las relaciones padre-hijo y pueden verse como una extensión de los modelos deterministas, como las redes booleanas (Somogyi y Sniegoski 1996). Si conocemos la verdadera estructura de G a priori, a partir de la Ecuación 11.1 podemos construir la función de probabilidad conjunta estimando cada probabilidad condicional. Sin embargo, en la estimación de la red genética no se conoce la verdadera G y tenemos que estimarla en función de los datos observados. Este problema puede considerarse un problema de selección de modelo estadístico. Describimos un criterio de selección de gráficos en la Sección II.A.3.

# %% [markdown]
# ### 👾 **Implementación de Redes Bayesianas con pgmpy**

# %%
### Codigo en python

# %% [markdown]
# ----
#
# ### 📑 **Avance de la Práctica**
#
# <div>
#   <input type="checkbox" id="check1" name="check1">
#   <label for="check1">Fundamentos de Redes Bayesianas</label>
#   <ul>
#     <li>
#       <input type="checkbox" id="subcheck1" name="subcheck1">
#       <label for="subcheck1">Investigación sobre Redes Bayesianas</label>
#     </li>
#     <li>
#       <input type="checkbox" id="subcheck2" name="subcheck2">
#       <label for="subcheck2">Diferencia entre Probabilidad Condicional e Independencia Condicional</label>
#     </li>
#     <li>
#       <input type="checkbox" id="subcheck2" name="subcheck2">
#       <label for="subcheck2">Representación Matemática de una Red Bayesiana</label>
#     </li>
#   </ul>
# </div>
#
# <div>
#   <input type="checkbox" id="check1" name="check1">
#   <label for="check1">Implementación de Redes Bayesianas con pgmpy</label>
#   <ul>
#     <li>
#       <input type="checkbox" id="subcheck1" name="subcheck1">
#       <label for="subcheck1">Instalar la Biblioteca pgmpy</label>
#     </li>
#     <li>
#       <input type="checkbox" id="subcheck2" name="subcheck2">
#       <label for="subcheck2">Crer una Red Bayesiana</label>
#     </li>
#     <li>
#       <input type="checkbox" id="subcheck2" name="subcheck2">
#       <label for="subcheck2">Tablas de Probabilidad Condicional</label>
#     </li>
#     <li>
#       <input type="checkbox" id="subcheck2" name="subcheck2">
#       <label for="subcheck2">Calcular la Probabilidad de Estar Satisfecho</label>
#     </li>
#   </ul>
# </div>
#
# <div>
#   <input type="checkbox" id="check1" name="check1">
#   <label for="check1">Análisis e Interpretación de Resultados UwU</label>
#   <ul>
#     <li>
#       <input type="checkbox" id="subcheck1" name="subcheck1">
#       <label for="subcheck1">Explica los Resultados Obtenidos en la Parte 2</label>
#     </li>
#     <li>
#       <input type="checkbox" id="subcheck2" name="subcheck2">
#       <label for="subcheck2">Ajusta las Probabilidades de las Tablas</label>
#     </li>
#     <li>
#       <input type="checkbox" id="subcheck2" name="subcheck2">
#       <label for="subcheck2">Plantea una Mejora de la Red Bayesiana Creada</label>
#     </li>
#   </ul>
# </div>
#
# ### ✅ **Entregables**
#
# <div>
#   <input type="checkbox" id="check1" name="check1">
#   <label for="check1">Código fuente del proyecto en un archivo .ipynb.</label>
# </div>
#
# <div>
#   <input type="checkbox" name="check1">
#   <label for="check1">Reporte en donde se explique la implementación, la experimentación y el análisis de los resultados.</label>
# </div>
